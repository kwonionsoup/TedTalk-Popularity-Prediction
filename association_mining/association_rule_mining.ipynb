# %% [markdown]
# ### 1. Read data into dataframes

# %%
import pandas as pd

data = pd.read_csv('../data/data_title_fully_processed.csv')
titles = data['processed_title']
data = pd.read_csv('../data/date_popularity_processed.csv')
popularity = data['popularity']
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_31872\2874931555.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### 2. Process text

# %%
title_tokens = []
for title in titles:
    title_tokens.append((str(title)).split(' '))

title_tokens[:10]
# Out:
# [['meet', 'founder', 'blog', 'revolution'],
#  ['averting', 'climate', 'crisis'],
#  ['simplicity', 'sell'],
#  ['chemical', 'scum', 'dream', 'distant', 'quasar'],
#  ['wish', 'global', 'day', 'film'],
#  ['love', 'cheat'],
#  ['happiness', 'body', 'soul'],
#  ['life', 'purpose'],
#  ['rebuild', 'broken', 'state'],
#  ['school', 'kill', 'creativity']]

# %% [markdown]
# ### 3. Run apriori association rule mining

# %%
from apyori import apriori
results = list(apriori(title_tokens, min_support = 0.001, min_confidence = 0.1))
print(len(results))
results[:10]
# Out:
# 81
# [RelationRecord(items=frozenset({'3', 'way'}), support=0.005150062155922571, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3'}), items_add=frozenset({'way'}), confidence=0.3918918918918919, lift=17.79631647776809), OrderedStatistic(items_base=frozenset({'way'}), items_add=frozenset({'3'}), confidence=0.2338709677419355, lift=17.79631647776809)]),
#  RelationRecord(items=frozenset({'4', 'way'}), support=0.0014207068016338128, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4'}), items_add=frozenset({'way'}), confidence=0.2424242424242424, lift=11.008797653958943)]),
#  RelationRecord(items=frozenset({'way', '5'}), support=0.0010655301012253596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'5'}), items_add=frozenset({'way'}), confidence=0.23076923076923078, lift=10.47952853598015)]),
#  RelationRecord(items=frozenset({'climate', 'action'}), support=0.0031965903036760787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'action'}), items_add=frozenset({'climate'}), confidence=0.6666666666666666, lift=36.44660194174757), OrderedStatistic(items_base=frozenset({'climate'}), items_add=frozenset({'action'}), confidence=0.17475728155339806, lift=36.44660194174757)]),
#  RelationRecord(items=frozenset({'body', 'affect'}), support=0.0010655301012253596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'affect'}), items_add=frozenset({'body'}), confidence=0.25, lift=35.19375), OrderedStatistic(items_base=frozenset({'body'}), items_add=frozenset({'affect'}), confidence=0.15, lift=35.19375)]),
#  RelationRecord(items=frozenset({'reality', 'augmented'}), support=0.0012431184514295863, ordered_statistics=[OrderedStatistic(items_base=frozenset({'augmented'}), items_add=frozenset({'reality'}), confidence=1.0, lift=201.10714285714283), OrderedStatistic(items_base=frozenset({'reality'}), items_add=frozenset({'augmented'}), confidence=0.25, lift=201.10714285714283)]),
#  RelationRecord(items=frozenset({'us', 'back'}), support=0.0012431184514295863, ordered_statistics=[OrderedStatistic(items_base=frozenset({'back'}), items_add=frozenset({'us'}), confidence=0.23333333333333334, lift=6.843229166666667)]),
#  RelationRecord(items=frozenset({'behind', 'story'}), support=0.0010655301012253596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'behind'}), items_add=frozenset({'story'}), confidence=0.16216216216216214, lift=10.495806150978563)]),
#  RelationRecord(items=frozenset({'help', 'better'}), support=0.0015982951518380393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'better'}), items_add=frozenset({'help'}), confidence=0.1232876712328767, lift=6.369108960663566)]),
#  RelationRecord(items=frozenset({'better', 'make'}), support=0.001775883502042266, ordered_statistics=[OrderedStatistic(items_base=frozenset({'better'}), items_add=frozenset({'make'}), confidence=0.136986301369863, lift=5.5896366885050615)])]

# %% [markdown]
# ### 4. Tune hyperparameters

# %% [markdown]
# ##### With confidence threshold of 0, no rules are found past a support threshold of 0.04.

# %%
results = list(apriori(title_tokens, min_support = 0.04, min_confidence = 0.0))
len(results)
# Out:
# 0

# %% [markdown]
# ##### Examine behavior of rule count wrt. support thresholds between (0, 0.04) at two different confidence thresholds.

# %%
import numpy as np
import matplotlib.pyplot as plot

support = np.arange(0.001, 0.04, 0.001)
rules0 = np.empty_like(support)
rules1 = np.empty_like(support)
for i, sup in enumerate(support):
    rules0[i] = len(list(apriori(title_tokens, min_support = sup, min_confidence = 0.0)))
    rules1[i] = len(list(apriori(title_tokens, min_support = sup, min_confidence = 0.1)))

# %%
plot.plot(support, rules0, label='Confidence >= 0')
plot.plot(support, rules1, label='Confidence >= 0.1')
plot.xlabel('Support Threshold')
plot.ylabel('Number of rules found')
plot.legend()

# %% [markdown]
# ##### By visual inspection, support threshold elbow appears to occur between 0.0025 and 0.0075.
# ##### Examine behavior of rule count wrt. confidence thresholds at support thresholds between 0.0025 and 0.0075.

# %%
conf = np.arange(0.0, 0.2, 0.001)
rules25 = np.empty_like(conf)
rules50 = np.empty_like(conf)
rules75 = np.empty_like(conf)
for i, cf in enumerate(conf):
    rules25[i] = len(list(apriori(title_tokens, min_support = 0.0025, min_confidence = cf)))
    rules50[i] = len(list(apriori(title_tokens, min_support = 0.005, min_confidence = cf)))
    rules75[i] = len(list(apriori(title_tokens, min_support = 0.0075, min_confidence = cf)))

# %%
cthresh = 0.01

plot.plot(conf, rules25, label='Support >= 0.0025')
plot.plot(conf, rules50, label='Support >= 0.005')
plot.plot(conf, rules75, label='Support >= 0.0075')
plot.vlines(cthresh, 0, 300, colors='black', label=f'Confidence = {cthresh}')

plot.xlabel('Confidence Threshold')
plot.ylabel('Number of rules found')
plot.legend()

# %% [markdown]
# ##### At this interval of support thresholds, defining the confidence threshold at 0.01 prevents rule count from blowing up.
# ##### Examine behavior of rule count wrt. support thresholds at confidence threshold of 0.01

# %%
rules01 = np.empty_like(support)
for i, sup in enumerate(support):
    rules01[i] = len(list(apriori(title_tokens, min_support = sup, min_confidence = cthresh)))

# %%
sthresh = 0.002
plot.plot(support, rules01, label='Confidence >= 0.01')
plot.vlines(sthresh, 0, 140, colors='black', label=f'Support = {sthresh}')

plot.xlabel('Support Threshold')
plot.ylabel('Number of rules found')
plot.legend()

# %% [markdown]
# ##### At a confidence threshold of 0.01, defining the support threshold at 0.002 prevents rule count from blowing up.

# %% [markdown]
# ### 5. Run apriori association rule mining with tuned hyperparameters

# %%
results = list(apriori(title_tokens, min_support = sthresh, min_confidence = cthresh))
title_rules = []
for rule in results:
    title_rules.append([rule.items, rule.support, rule.ordered_statistics[0].confidence])
df = pd.DataFrame(title_rules, columns=['Set', 'Support', 'Confidence'])

# %% [markdown]
# ##### Sort sets by highest support

# %%
df.sort_values(by=['Support'], ascending=False)
# Out:
#                   Set   Support  Confidence
# 17             (life)  0.036583    0.036583
# 36            (world)  0.035518    0.035518
# 32               (us)  0.034097    0.034097
# 9            (future)  0.025573    0.025573
# 20             (make)  0.024507    0.024507
# 22              (new)  0.023797    0.023797
# 33              (way)  0.022021    0.022021
# 4            (change)  0.021311    0.021311
# 21             (need)  0.020067    0.020067
# 7             (could)  0.019890    0.019890
# 13             (help)  0.019357    0.019357
# 35             (work)  0.018292    0.018292
# 6           (climate)  0.018292    0.018292
# 1               (art)  0.016693    0.016693
# 14          (history)  0.015983    0.015983
# 3             (brain)  0.015805    0.015805
# 25            (power)  0.015805    0.015805
# 15            (human)  0.015628    0.015628
# 30            (story)  0.015450    0.015450
# 24           (people)  0.015450    0.015450
# 29            (solve)  0.013852    0.013852
# 18             (like)  0.013497    0.013497
# 34            (woman)  0.013319    0.013319
# 0                 (3)  0.013142    0.013142
# 28           (secret)  0.012964    0.012964
# 23              (one)  0.012964    0.012964
# 2            (better)  0.012964    0.012964
# 31             (time)  0.012609    0.012609
# 5              (city)  0.012609    0.012609
# 16              (let)  0.012254    0.012254
# 10              (get)  0.012076    0.012076
# 27          (science)  0.011721    0.011721
# 26           (riddle)  0.010833    0.010833
# 19             (love)  0.010655    0.010655
# 12           (health)  0.010478    0.010478
# 8            (design)  0.010478    0.010478
# 11           (global)  0.010123    0.010123
# 47          (let, us)  0.010123    0.010123
# 53    (riddle, solve)  0.009767    0.901639
# 41  (climate, change)  0.008879    0.416667
# 37           (3, way)  0.005150    0.391892
# 52         (new, way)  0.004085    0.171642
# 55        (teach, us)  0.004085    0.460000
# 42    (could, change)  0.003197    0.150000
# 38  (climate, action)  0.003197    0.666667
# 40     (care, health)  0.003197    0.580645
# 46         (help, us)  0.002664    0.137615
# 48       (like, look)  0.002664    0.197368
# 50         (make, us)  0.002664    0.108696
# 43      (help, could)  0.002486    0.125000
# 45   (mental, health)  0.002486    0.237288
# 54      (story, tell)  0.002486    0.160920
# 44        (day, life)  0.002309    0.351351
# 49      (like, think)  0.002309    0.171053
# 51      (world, need)  0.002309    0.115044
# 39   (brief, history)  0.002131    0.923077

# %% [markdown]
# ##### Sort sets by highest confidence

# %%
df.sort_values(by=['Confidence'], ascending=False)
# Out:
#                   Set   Support  Confidence
# 39   (brief, history)  0.002131    0.923077
# 53    (riddle, solve)  0.009767    0.901639
# 38  (climate, action)  0.003197    0.666667
# 40     (care, health)  0.003197    0.580645
# 55        (teach, us)  0.004085    0.460000
# 41  (climate, change)  0.008879    0.416667
# 37           (3, way)  0.005150    0.391892
# 44        (day, life)  0.002309    0.351351
# 45   (mental, health)  0.002486    0.237288
# 48       (like, look)  0.002664    0.197368
# 52         (new, way)  0.004085    0.171642
# 49      (like, think)  0.002309    0.171053
# 54      (story, tell)  0.002486    0.160920
# 42    (could, change)  0.003197    0.150000
# 46         (help, us)  0.002664    0.137615
# 43      (help, could)  0.002486    0.125000
# 51      (world, need)  0.002309    0.115044
# 50         (make, us)  0.002664    0.108696
# 17             (life)  0.036583    0.036583
# 36            (world)  0.035518    0.035518
# 32               (us)  0.034097    0.034097
# 9            (future)  0.025573    0.025573
# 20             (make)  0.024507    0.024507
# 22              (new)  0.023797    0.023797
# 33              (way)  0.022021    0.022021
# 4            (change)  0.021311    0.021311
# 21             (need)  0.020067    0.020067
# 7             (could)  0.019890    0.019890
# 13             (help)  0.019357    0.019357
# 35             (work)  0.018292    0.018292
# 6           (climate)  0.018292    0.018292
# 1               (art)  0.016693    0.016693
# 14          (history)  0.015983    0.015983
# 3             (brain)  0.015805    0.015805
# 25            (power)  0.015805    0.015805
# 15            (human)  0.015628    0.015628
# 24           (people)  0.015450    0.015450
# 30            (story)  0.015450    0.015450
# 29            (solve)  0.013852    0.013852
# 18             (like)  0.013497    0.013497
# 34            (woman)  0.013319    0.013319
# 0                 (3)  0.013142    0.013142
# 23              (one)  0.012964    0.012964
# 2            (better)  0.012964    0.012964
# 28           (secret)  0.012964    0.012964
# 31             (time)  0.012609    0.012609
# 5              (city)  0.012609    0.012609
# 16              (let)  0.012254    0.012254
# 10              (get)  0.012076    0.012076
# 27          (science)  0.011721    0.011721
# 26           (riddle)  0.010833    0.010833
# 19             (love)  0.010655    0.010655
# 12           (health)  0.010478    0.010478
# 8            (design)  0.010478    0.010478
# 47          (let, us)  0.010123    0.010123
# 11           (global)  0.010123    0.010123

# %% [markdown]
# ##### What if we want to exclude single word clusters? Observe that the lowest confidence of a two-word cluster with our current metrics is 0.108696, while the highest confidence of a one-word cluster is 0.036583. Setting a minimum confidence threshold of 0.1 would eliminate all one-word clusters.

# %%
results = list(apriori(title_tokens, min_support = sthresh, min_confidence = 0.1))
title_rules = []
for rule in results:
    title_rules.append([rule.items, rule.support, rule.ordered_statistics[0].confidence])
df = pd.DataFrame(title_rules, columns=['Set', 'Support', 'Confidence'])
df.sort_values(by=['Support'], ascending=False)
# Out:
#                   Set   Support  Confidence
# 10          (let, us)  0.010123    0.826087
# 16    (riddle, solve)  0.009767    0.901639
# 4   (climate, change)  0.008879    0.416667
# 0            (3, way)  0.005150    0.391892
# 15         (new, way)  0.004085    0.171642
# 18        (teach, us)  0.004085    0.460000
# 1   (climate, action)  0.003197    0.666667
# 5     (could, change)  0.003197    0.150000
# 3      (care, health)  0.003197    0.580645
# 11       (like, look)  0.002664    0.197368
# 13         (make, us)  0.002664    0.108696
# 9          (help, us)  0.002664    0.137615
# 6       (help, could)  0.002486    0.125000
# 8    (mental, health)  0.002486    0.237288
# 17      (story, tell)  0.002486    0.160920
# 7         (day, life)  0.002309    0.351351
# 12      (like, think)  0.002309    0.171053
# 14      (world, need)  0.002309    0.115044
# 2    (brief, history)  0.002131    0.923077

# %% [markdown]
# ##### It is intuitive that larger word clusters will have lower support values than one-word clusters. With a much higher confidence threshold, we can reduce the support threshold to 0.001 without producing too many clusters.

# %%
results = list(apriori(title_tokens, min_support = 0.001, min_confidence = 0.1))
title_rules = []
for rule in results:
    title_rules.append([rule.items, rule.support, rule.ordered_statistics[0].confidence])
df = pd.DataFrame(title_rules, columns=['Set', 'Support', 'Confidence'])
df.sort_values(by=['Support'], ascending=False)
# Out:
#                    Set   Support  Confidence
# 54           (let, us)  0.010123    0.826087
# 69     (riddle, solve)  0.009767    0.901639
# 17   (climate, change)  0.008879    0.416667
# 0             (3, way)  0.005150    0.391892
# 73         (teach, us)  0.004085    0.460000
# ..                 ...       ...         ...
# 19      (design, city)  0.001066    0.101695
# 26  (crisis, solution)  0.001066    0.133333
# 52        (know, need)  0.001066    0.122449
# 48     (ugly, history)  0.001066    0.857143
# 65         (one, year)  0.001066    0.206897
#
# [81 rows x 3 columns]
